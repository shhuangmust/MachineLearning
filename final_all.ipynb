# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from fake_useragent import UserAgent
import random
#import string
import time

# %%
options = Options() 

ua = UserAgent()
userAgent = ua.random

options.add_argument(f'user-agent={userAgent}')
options.add_argument('--headless')  # 非本機執行，必須啟動Headless模式
options.add_argument('--disable-gpu') # 關閉GPU 避免某些系統或是網頁出錯

service = Service()
driver = webdriver.Chrome(service=service, options=options)
url = 'http://120.105.96.87/register_all.html'
driver.get(url)

# %%
from selenium.webdriver.support.ui import Select

myid = driver.find_element(By.NAME, "id")
myid.clear()
myid.send_keys("shhuang") # 請輸入你的學號

myemail = driver.find_element(By.NAME, "email")
myemail.clear()
myemail.send_keys("shhuang@must.edu.tw") # 請輸入你的email

passwd = driver.find_element(By.NAME, "pwd")
passwd.clear()
passwd.send_keys("shhuang")  # 請輸入你要設定的登入密碼

sex=driver.find_element(By.ID, "f") # 請輸入你要點選的性別：f、m、s
#sex=driver.find_element(By.XPATH, "//input[@value='f']")
sex.click()

interest=driver.find_element(By.ID, "tv") # 請輸入你要點選的興趣：tv、movie、bike
interest.click()
interest1=driver.find_element(By.ID, "movie") # 請輸入你要點選的興趣：tv、movie、bike，注意，movie是預設點選
interest1.click()
interest2=driver.find_element(By.ID, "bike") # 請輸入你要點選的興趣：tv、movie、bike
interest2.click()


county = Select(driver.find_element(By.NAME, 'county'))
county.select_by_value("hsinchu") # 請輸入你要設定的縣市 taoyuan(桃園)、hsinchu(新竹縣/市)、miaoli(苗栗)、others(其他)

driver.get_screenshot_as_file('data5.png') # 註冊畫面
mysubmit = WebDriverWait(driver, 5).until(EC.presence_of_element_located((By.NAME, "submit")))
mysubmit.submit()
time.sleep(1)
driver.get_screenshot_as_file('data6.png') # 註冊結果畫面
driver.close()
